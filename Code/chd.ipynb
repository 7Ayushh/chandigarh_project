# %% [markdown]
# <a href="https://colab.research.google.com/github/7Ayushh/Cp-SOC-Ayushh/blob/main/chd.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#upload files - standard code
# from google.colab import files
# uploaded= files.upload()
#importing librarires
import pandas as pd
# import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_csv("duplicatekaduplicate - Sheet1.csv")
df.head()
# Out:
#   Place of current residence     Sex    Age Religion     Place of birth  \
# 0                    Maloya     Male  31-40    Hindu  Inside Chandigarh
# 1                     Maloya    Male  21-30    Hindu  Inside Chandigarh
# 2                     Maloya    Male  14-20    Hindu  Inside Chandigarh
# 3                     Maloya  Female  41-50    Hindu                NaN
# 4                     Maloya  Female    60+    Hindu  Inside Chandigarh
#
#   Level of Education  Since when do you live here?(years)  Job Sector  \
# 0       Not educated                                  1.5    Informal
# 1          10th pass                                  3.5    Informal
# 2           8th pass                                  3.5    Informal
# 3       Not educated                                  5.0  Unemployed
# 4       Not educated                                  5.0  Unemployed
#
#   Do you earn a fixed salary or a daily wage?  \
# 0                                         NaN
# 1                                Fixed salary
# 2                                Fixed salary
# 3                                         NaN
# 4                                         NaN
#
#   What is the distance between your home and your workplace?  ...  \
# 0                                       < 15 minutes          ...
# 1                                    15 - 30 minutes          ...
# 2                                    15 - 30 minutes          ...
# 3                                                NaN          ...
# 4                                                NaN          ...
#
#   How is the law and order situation (mahaul) compared to where you lived before?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                               Same
# 4                                               Same
#
#   Do you feel safe to walk alone at night in your community?  \
# 0                                           Somewhat
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Does the street lighting work?  \
# 0                        Somewhat
# 1                             Yes
# 2                             Yes
# 3                             Yes
# 4                             Yes
#
#   How are your relations with your neighbours?  \
# 0                                         Good
# 1                                      Neutral
# 2                                      Neutral
# 3                                         Good
# 4                                         Good
#
#   If you have any small illnesses where do you get them treated?  \
# 0                                  Clinic/Dispensary
# 1                                  Clinic/Dispensary
# 2                                                NaN
# 3                                  Clinic/Dispensary
# 4                                  Clinic/Dispensary
#
#   How satisfied are you with the services? (mostly for dispensaries)  \
# 0                                      Not satisfied
# 1                                      Not satisfied
# 2                                                NaN
# 3                                      Not satisfied
# 4                                      Not satisfied
#
#   What was the nature of your movement? How they are viewed changed or not?  \
# 0                             Voluntary                                  No
# 1                                Forced                           Yes (-ve)
# 2                                Forced                                 NaN
# 3                                Forced                                 NaN
# 4                                Forced                                 NaN
#
#   How they view people has changed  \
# 0                              NaN
# 1                        Yes (-ve)
# 2                              NaN
# 3                              NaN
# 4                              NaN
#
#   If given a chance, would you retrace your steps and go back to your previous location?
# 0                                                NaN
# 1                                                Yes
# 2                                                Yes
# 3                                                Yes
# 4                                                Yes
#
# [5 rows x 44 columns]

# %%
df2 = df[df['What was the nature of your movement?'].notna()]
df2
# Out:
#     Place of current residence     Sex    Age       Religion  \
# 0                      Maloya     Male  31-40          Hindu
# 1                       Maloya    Male  21-30          Hindu
# 2                       Maloya    Male  14-20          Hindu
# 3                       Maloya  Female  41-50          Hindu
# 4                       Maloya  Female    60+          Hindu
# 5                       Maloya  Female  51-60          Hindu
# 6                       Maloya  Female  51-60          Hindu
# 7                       Maloya    Male  41-50          Hindu
# 9                    Sector 49    Male  51-60  Not mentioned
# 15                   Sector 49    Male    60+           Sikh
# 17                   Sector 49  Female  41-50  Not mentioned
# 18                   Sector 49    Male  21-30            NaN
# 19                   Sector 49    Male  14-20          Hindu
# 20                   Sector 49    Male  14-20          Hindu
# 21  Mauli Jagran 2/Sundarnagar    Male  14-20            NaN
# 22  Mauli Jagran 2/Sundarnagar    Male  14-20            NaN
# 23  Mauli Jagran 2/Sundarnagar    Male  21-30          Hindu
# 24  Mauli Jagran 2/Sundarnagar    Male  14-20          Hindu
# 25  Mauli Jagran 2/Sundarnagar  Female  41-50          Hindu
# 26                      Dhanas    Male  14-20            NaN
# 27                      Dhanas    Male  14-20          Hindu
# 28                      Dhanas    Male  31-40          Hindu
# 29                      Dhanas    Male  41-50            NaN
# 33                      Dhanas  Female  31-40  Not mentioned
# 34                      Dhanas  Female  31-40  Not mentioned
# 36                      Dhanas    Male  51-60  Not mentioned
# 40                  Ram Darbar    Male  21-30          Hindu
# 41                  Ram Darbar    Male  41-50           Sikh
# 42                  Ram Darbar    Male  21-30            NaN
# 43                  Ram Darbar    Male  21-30          Hindu
# 44                  Ram Darbar    Male  14-20          Hindu
# 45                  Ram Darbar    Male  14-20          Hindu
# 46                  Ram Darbar  Female  41-50          Hindu
# 47                     Maloya     Male  14-20            NaN
# 48                     Maloya     Male  14-20            NaN
# 49                     Maloya     Male  51-60        Valmiki
# 53                  Ram Darbar  Female    NaN  Not mentioned
# 54                  Ram Darbar  Female  31-40          Hindu
# 55                  Ram Darbar  Female  41-50          Hindu
# 56                  Ram Darbar  Female  31-40          Hindu
# 58  Mauli Jagran 2/Sundarnagar    Male  21-30         Muslim
# 59  Mauli Jagran 2/Sundarnagar  Female  31-40            NaN
# 68                  Sector 38W    Male  31-40  Not mentioned
#
#         Place of birth        Level of Education  \
# 0    Inside Chandigarh              Not educated
# 1    Inside Chandigarh                 10th pass
# 2    Inside Chandigarh                  8th pass
# 3                  NaN              Not educated
# 4    Inside Chandigarh              Not educated
# 5                  NaN              Not educated
# 6                  NaN              Not educated
# 7    Inside Chandigarh              Not educated
# 9                  NaN                       NaN
# 15  Outside Chandigarh                       NaN
# 17                 NaN                       NaN
# 18           Panchkula                   College
# 19                 NaN                 10th pass
# 20                 NaN                  8th pass
# 21   Inside Chandigarh                 10th pass
# 22   Inside Chandigarh                  8th pass
# 23   Inside Chandigarh                   College
# 24   Inside Chandigarh                       NaN
# 25   Inside Chandigarh              Not educated
# 26   Inside Chandigarh                 12th pass
# 27  Outside Chandigarh                 10th pass
# 28                 NaN  Currently studying/Other
# 29                 NaN              Not educated
# 33                 NaN                       NaN
# 34                 NaN                       NaN
# 36                 NaN                       NaN
# 40   Inside Chandigarh                  9th pass
# 41   Inside Chandigarh                 6th class
# 42   Inside Chandigarh                       NaN
# 43   Inside Chandigarh                   College
# 44   Inside Chandigarh                 10th pass
# 45   Inside Chandigarh                 10th pass
# 46   Inside Chandigarh                       NaN
# 47   Inside Chandigarh  Currently studying/Other
# 48   Inside Chandigarh                  8th pass
# 49  Outside Chandigarh              Not educated
# 53                 NaN                       NaN
# 54                 NaN                 12th pass
# 55                 NaN              Not educated
# 56                 NaN                       NaN
# 58  Outside Chandigarh                 10th pass
# 59  Outside Chandigarh                       NaN
# 68  Outside Chandigarh                       NaN
#
#     Since when do you live here?(years)  Job Sector  \
# 0                                  1.50    Informal
# 1                                  3.50    Informal
# 2                                  3.50    Informal
# 3                                  5.00  Unemployed
# 4                                  5.00  Unemployed
# 5                                  5.00  Unemployed
# 6                                  5.00  Unemployed
# 7                                  3.50    Informal
# 9                                 12.00         NaN
# 15                                15.00    Informal
# 17                                11.00    Informal
# 18                                13.00     Student
# 19                                15.50    Informal
# 20                                15.50  Unemployed
# 21                                 8.00     Student
# 22                                 6.00     Student
# 23                                 5.50      Formal
# 24                                  NaN         NaN
# 25                                 6.50  Unemployed
# 26                                12.50    Informal
# 27                                 2.00     Student
# 28                                11.00    Informal
# 29                                10.00    Informal
# 33                                 9.00         NaN
# 34                                 9.00         NaN
# 36                                10.00         NaN
# 40                                11.50    Informal
# 41                                 1.00    Informal
# 42                                13.00         NaN
# 43                                 4.50         NaN
# 44                                 4.50         NaN
# 45                                 4.50         NaN
# 46                                 4.50         NaN
# 47                                 2.00     Student
# 48                                 0.25    Informal
# 49                                 2.50    Informal
# 53                                 8.50    Informal
# 54                                11.00  Unemployed
# 55                                11.00    Informal
# 56                                11.00         NaN
# 58                                 0.25    Informal
# 59                                 5.00         NaN
# 68                                13.50      Formal
#
#    Do you earn a fixed salary or a daily wage?  \
# 0                                          NaN
# 1                                 Fixed salary
# 2                                 Fixed salary
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                   Daily wage
# 9                                          NaN
# 15                                         NaN
# 17                                  Daily wage
# 18                                         NaN
# 19                                         NaN
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                Fixed salary
# 24                                         NaN
# 25                                         NaN
# 26                                  Daily wage
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
# 33                                         NaN
# 34                                         NaN
# 36                                         NaN
# 40                                Fixed salary
# 41                                         NaN
# 42                                         NaN
# 43                                         NaN
# 44                                         NaN
# 45                                         NaN
# 46                                         NaN
# 47                                         NaN
# 48                                Fixed salary
# 49                                Fixed salary
# 53                                         NaN
# 54                                         NaN
# 55                                  Daily wage
# 56                                         NaN
# 58                                  Daily wage
# 59                                         NaN
# 68                                Fixed salary
#
#    What is the distance between your home and your workplace?  ...  \
# 0                                        < 15 minutes          ...
# 1                                     15 - 30 minutes          ...
# 2                                     15 - 30 minutes          ...
# 3                                                 NaN          ...
# 4                                                 NaN          ...
# 5                                                 NaN          ...
# 6                                                 NaN          ...
# 7                                            Variable          ...
# 9                                                 NaN          ...
# 15                                                NaN          ...
# 17                                                NaN          ...
# 18                                                NaN          ...
# 19                                                NaN          ...
# 20                                                NaN          ...
# 21                                                NaN          ...
# 22                                                NaN          ...
# 23                                       < 15 minutes          ...
# 24                                                NaN          ...
# 25                                                NaN          ...
# 26                                    15 - 30 minutes          ...
# 27                                                NaN          ...
# 28                                       >45  minutes          ...
# 29                                       >45  minutes          ...
# 33                                                NaN          ...
# 34                                                NaN          ...
# 36                                                NaN          ...
# 40                                       < 15 minutes          ...
# 41                                    15 - 30 minutes          ...
# 42                                                NaN          ...
# 43                                                NaN          ...
# 44                                                NaN          ...
# 45                                                NaN          ...
# 46                                                NaN          ...
# 47                                                NaN          ...
# 48                                    30 - 45 minutes          ...
# 49                                                NaN          ...
# 53                                                NaN          ...
# 54                                                NaN          ...
# 55                                                NaN          ...
# 56                                                NaN          ...
# 58                                       < 15 minutes          ...
# 59                                                NaN          ...
# 68                                                NaN          ...
#
#    How is the law and order situation (mahaul) compared to where you lived before?  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                Same
# 4                                                Same
# 5                                                Same
# 6                                                Same
# 7                                                 NaN
# 9                                                 NaN
# 15                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                         Don't know
# 22                                         Don't know
# 23                                              Worse
# 24                                              Worse
# 25                                             Better
# 26                                             Better
# 27                                         Don't know
# 28                                              Worse
# 29                                              Worse
# 33                                               Same
# 34                                                NaN
# 36                                                NaN
# 40                                         Don't know
# 41                                         Don't know
# 42                                              Worse
# 43                                             Better
# 44                                             Better
# 45                                             Better
# 46                                             Better
# 47                                         Don't know
# 48                                         Don't know
# 49                                               Same
# 53                                                NaN
# 54                                              Worse
# 55                                              Worse
# 56                                              Worse
# 58                                                NaN
# 59                                              Worse
# 68                                              Worse
#
#    Do you feel safe to walk alone at night in your community?  \
# 0                                            Somewhat
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 9                                                 NaN
# 15                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                 No
# 20                                                 No
# 21                                           Somewhat
# 22                                           Somewhat
# 23                                                Yes
# 24                                                Yes
# 25                                                Yes
# 26                                                Yes
# 27                                           Somewhat
# 28                                                 No
# 29                                                 No
# 33                                                NaN
# 34                                                NaN
# 36                                                NaN
# 40                                                 No
# 41                                           Somewhat
# 42                                           Somewhat
# 43                                           Somewhat
# 44                                           Somewhat
# 45                                           Somewhat
# 46                                           Somewhat
# 47                                           Somewhat
# 48                                           Somewhat
# 49                                                NaN
# 53                                                NaN
# 54                                                NaN
# 55                                                NaN
# 56                                                NaN
# 58                                                NaN
# 59                                                NaN
# 68                                                 No
#
#     Does the street lighting work?  \
# 0                         Somewhat
# 1                              Yes
# 2                              Yes
# 3                              Yes
# 4                              Yes
# 5                              Yes
# 6                              Yes
# 7                              Yes
# 9                              NaN
# 15                             NaN
# 17                             NaN
# 18                             Yes
# 19                             Yes
# 20                             Yes
# 21                             Yes
# 22                             Yes
# 23                             NaN
# 24                             NaN
# 25                             NaN
# 26                             Yes
# 27                             Yes
# 28                             Yes
# 29                             Yes
# 33                             NaN
# 34                             NaN
# 36                             Yes
# 40                             Yes
# 41                              No
# 42                        Somewhat
# 43                             Yes
# 44                             Yes
# 45                             Yes
# 46                             Yes
# 47                             Yes
# 48                             Yes
# 49                             NaN
# 53                             NaN
# 54                             Yes
# 55                             Yes
# 56                             Yes
# 58                        Somewhat
# 59                        Somewhat
# 68                             Yes
#
#    How are your relations with your neighbours?  \
# 0                                          Good
# 1                                       Neutral
# 2                                       Neutral
# 3                                          Good
# 4                                          Good
# 5                                          Good
# 6                                          Good
# 7                                       Neutral
# 9                                          Good
# 15                                          NaN
# 17                                          Bad
# 18                                          NaN
# 19                                         Good
# 20                                         Good
# 21                                          NaN
# 22                                          Bad
# 23                                      Neutral
# 24                                          NaN
# 25                                          NaN
# 26                                      Neutral
# 27                                      Neutral
# 28                                          Bad
# 29                                          Bad
# 33                                          NaN
# 34                                          NaN
# 36                                      Neutral
# 40                                         Good
# 41                                         Good
# 42                                          Bad
# 43                                         Good
# 44                                         Good
# 45                                         Good
# 46                                         Good
# 47                                      Neutral
# 48                                      Neutral
# 49                                         Good
# 53                                          NaN
# 54                                      Neutral
# 55                                      Neutral
# 56                                      Neutral
# 58                                      Neutral
# 59                                      Neutral
# 68                                      Neutral
#
#    If you have any small illnesses where do you get them treated?  \
# 0                                   Clinic/Dispensary
# 1                                   Clinic/Dispensary
# 2                                                 NaN
# 3                                   Clinic/Dispensary
# 4                                   Clinic/Dispensary
# 5                                   Clinic/Dispensary
# 6                                   Clinic/Dispensary
# 7                                Government hospital
# 9                                   Clinic/Dispensary
# 15                                  Clinic/Dispensary
# 17                                  Clinic/Dispensary
# 18                                  Clinic/Dispensary
# 19                                  Clinic/Dispensary
# 20                                  Clinic/Dispensary
# 21                                     Private clinic
# 22                                            Chemist
# 23                                  Clinic/Dispensary
# 24                                  Clinic/Dispensary
# 25                               Government hospital
# 26                                   Private hospital
# 27                                  Clinic/Dispensary
# 28                                  Clinic/Dispensary
# 29                                  Clinic/Dispensary
# 33                                  Clinic/Dispensary
# 34                                  Clinic/Dispensary
# 36                                  Clinic/Dispensary
# 40                                  Clinic/Dispensary
# 41                                     Private clinic
# 42                                  Clinic/Dispensary
# 43                                  Clinic/Dispensary
# 44                                  Clinic/Dispensary
# 45                                  Clinic/Dispensary
# 46                                  Clinic/Dispensary
# 47                                  Clinic/Dispensary
# 48                                  Clinic/Dispensary
# 49                                   Private hospital
# 53                                  Clinic/Dispensary
# 54                                  Clinic/Dispensary
# 55                                  Clinic/Dispensary
# 56                                  Clinic/Dispensary
# 58                                  Clinic/Dispensary
# 59                                                NaN
# 68                                  Clinic/Dispensary
#
#    How satisfied are you with the services? (mostly for dispensaries)  \
# 0                                       Not satisfied
# 1                                       Not satisfied
# 2                                                 NaN
# 3                                       Not satisfied
# 4                                       Not satisfied
# 5                                       Not satisfied
# 6                                       Not satisfied
# 7                                       Not satisfied
# 9                                           Satisfied
# 15                                                NaN
# 17                                                NaN
# 18                                          Satisfied
# 19                                                NaN
# 20                                                NaN
# 21                                          Satisfied
# 22                                          Satisfied
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                 Somewhat satisfied
# 27                                          Satisfied
# 28                                          Satisfied
# 29                                          Satisfied
# 33                                          Satisfied
# 34                                          Satisfied
# 36                                          Satisfied
# 40                                          Satisfied
# 41                                 Somewhat satisfied
# 42                                 Somewhat satisfied
# 43                                 Somewhat satisfied
# 44                                 Somewhat satisfied
# 45                                 Somewhat satisfied
# 46                                 Somewhat satisfied
# 47                                 Somewhat satisfied
# 48                                 Somewhat satisfied
# 49                                 Somewhat satisfied
# 53                                          Satisfied
# 54                                          Satisfied
# 55                                          Satisfied
# 56                                          Satisfied
# 58                                                NaN
# 59                                                NaN
# 68                                 Somewhat satisfied
#
#    What was the nature of your movement? How they are viewed changed or not?  \
# 0                              Voluntary                                  No
# 1                                 Forced                           Yes (-ve)
# 2                                 Forced                                 NaN
# 3                                 Forced                                 NaN
# 4                                 Forced                                 NaN
# 5                                 Forced                                 NaN
# 6                                 Forced                                 NaN
# 7                             Don't know                                  No
# 9                              Voluntary                           Yes (+ve)
# 15                             Voluntary                                 NaN
# 17                             Voluntary                                 NaN
# 18                                Forced                                  No
# 19                                Forced                                 NaN
# 20                                Forced                                 NaN
# 21                            Don't know                           Yes (+ve)
# 22                            Don't know                                 NaN
# 23                                Forced                                  No
# 24                                Forced                                 NaN
# 25                                Forced                                 NaN
# 26                             Voluntary                             Unclear
# 27                             Voluntary                                  No
# 28                                Forced                                 NaN
# 29                                Forced                                 NaN
# 33                             Voluntary                                 NaN
# 34                             Voluntary                                 NaN
# 36                            Don't know                                 NaN
# 40                            Don't know                           Yes (-ve)
# 41                            Don't know                           Yes (-ve)
# 42                                Forced                           Yes (-ve)
# 43                            Don't know                                 NaN
# 44                            Don't know                           Yes (+ve)
# 45                            Don't know                                  No
# 46                            Don't know                                 NaN
# 47                            Don't know                                  No
# 48                            Don't know                                 NaN
# 49                                Forced                                 NaN
# 53                            Don't know                                 NaN
# 54                            Don't know                                 NaN
# 55                            Don't know                           Yes (-ve)
# 56                            Don't know                           Yes (-ve)
# 58                             Voluntary                                 NaN
# 59                                Forced                                 NaN
# 68                                Forced                                  No
#
#    How they view people has changed  \
# 0                               NaN
# 1                         Yes (-ve)
# 2                               NaN
# 3                               NaN
# 4                               NaN
# 5                               NaN
# 6                               NaN
# 7                               NaN
# 9                         Yes (+ve)
# 15                              NaN
# 17                              NaN
# 18                              NaN
# 19                              NaN
# 20                              NaN
# 21                              NaN
# 22                              NaN
# 23                              NaN
# 24                        Yes (+ve)
# 25                              NaN
# 26                              NaN
# 27                              NaN
# 28                              NaN
# 29                              NaN
# 33                              NaN
# 34                              NaN
# 36                              NaN
# 40                              NaN
# 41                              NaN
# 42                              NaN
# 43                              NaN
# 44                              NaN
# 45                              NaN
# 46                              NaN
# 47                              NaN
# 48                              NaN
# 49                              NaN
# 53                              NaN
# 54                              NaN
# 55                              NaN
# 56                              NaN
# 58                              NaN
# 59                              NaN
# 68                              NaN
#
#    If given a chance, would you retrace your steps and go back to your previous location?
# 0                                                 NaN
# 1                                                 Yes
# 2                                                 Yes
# 3                                                 Yes
# 4                                                 Yes
# 5                                                 Yes
# 6                                                 Yes
# 7                                                 NaN
# 9                                                 NaN
# 15                                                NaN
# 17                                                Yes
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                 No
# 22                                                Yes
# 23                                                 No
# 24                                                 No
# 25                                                 No
# 26                                                 No
# 27                                                 No
# 28                                          Not clear
# 29                                          Not clear
# 33                                                NaN
# 34                                                NaN
# 36                                                 No
# 40                                                Yes
# 41                                                NaN
# 42                                                Yes
# 43                                                 No
# 44                                                 No
# 45                                                 No
# 46                                                 No
# 47                                                 No
# 48                                                 No
# 49                                                Yes
# 53                                                 No
# 54                                                Yes
# 55                                                Yes
# 56                                                Yes
# 58                                                 No
# 59                                                NaN
# 68                                          Not clear
#
# [43 rows x 44 columns]

# %%
grouped_data = df.groupby(['What was the nature of your movement?', 'Place of current residence']).size().unstack()

# Plotting the grouped chart
grouped_data.plot(kind='bar', stacked=True)

# Set labels and title
plt.xlabel('Nature')
plt.ylabel('Count')
plt.title('Residence and Nature')

legend=plt.legend(title='Residence')
legend.get_title().set_fontsize('12')

plt.show()

# %%
grouped_data = df2.groupby(['What was the nature of your movement?', 'Sex']).size().unstack()

# Plotting the clustered chart
grouped_data.plot(kind='bar', stacked=True)

# Add labels and title
plt.xlabel('Movement type')
plt.ylabel('Number of People')
plt.title('Sex Division by Place of Residence')

# Show the plot
plt.show()

# %%
df2.plot(x="What was the nature of your movement?", y=["Percentage1", "Percentage2"], kind="bar")

# %%
# Get the unique places of residence
residences = grouped_data.index

# Set the width of each bar
bar_width = 0.35

# Create an array of indices for the x-axis ticks
ind = np.arange(len(residences))

# Plotting the clustered chart
fig, ax = plt.subplots()
male_bars = ax.bar(ind, grouped_data['Male'], width=bar_width, label='Male')
female_bars = ax.bar(ind + bar_width, grouped_data['Female'], width=bar_width, label='Female')

# Add labels and title
ax.set_xlabel('Movement')
ax.set_ylabel('Number of People')
ax.set_title('Sex Division by Place of Residence')

# Set the x-axis ticks and labels
ax.set_xticks(ind + bar_width / 2)
ax.set_xticklabels(residences)

# Add a legend
ax.legend()

# Show the plot
plt.show()

# %%
subset_male = df2[df2['Sex'] == 'Male']
residence_percentage = subset_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage of Men')
plt.title('Percentage of Movement type reported by men')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.legend(['Men'])

plt.show()

# %%
subset_male = df2[df2['Sex'] == 'Female']
residence_percentage = subset_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage of Women')
plt.title('Percentage of Movement type reported by Women')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.legend(['Women'])

plt.show()

# %%
maloya_male = df2[df2['Place of current residence'] == 'Maloya']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('Percentage of Movement type in Maloya')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
rd_data = df2[df2['Place of current residence'] == 'Ram Darbar']
residence_percentage = rd_data['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('Percentage of Movement type in Ram Darbar')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
maloya_male = df2[df2['Place of current residence'] == 'Sector 49']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('Percentage of Movement type in Sec49')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
maloya_male = df2[df2['Place of current residence'] == 'Sector 38W']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('Percentage of Movement type in Sec38')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
maloya_male = df2[df2['Place of current residence'] == 'Dhanas']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('Percentage of Movement type in Dhanas')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
maloya_male = df2[df2['Place of current residence'] == 'Mauli Jagran 2/Sundarnagar']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('Percentage of Movement type in Mauli Jagran')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
import matplotlib.pyplot as plt

# Filter data for men
male_data = df[df['Sex'] == 'Male']
male_residence_percentage = male_data['What was the nature of your movement?'].value_counts(normalize=True) * 100

# Filter data for women
female_data = df[df['Sex'] == 'Female']
female_residence_percentage = female_data['What was the nature of your movement?'].value_counts(normalize=True) * 100

# Create the bar plot
ax = plt.subplot(111)
ax.bar(male_residence_percentage.index, male_residence_percentage.values, label='Men')
ax.bar(female_residence_percentage.index, female_residence_percentage.values, label='Women')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('Percentage of Men and Women reporting different types of movement')
plt.legend()

# Add percentage labels to the top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Filter data for men
male_data = df[df['Sex'] == 'Male']
male_residence_percentage = male_data['What was the nature of your movement?'].value_counts(normalize=True) * 100

# Filter data for women
female_data = df[df['Sex'] == 'Female']
female_residence_percentage = female_data['What was the nature of your movement?'].value_counts(normalize=True) * 100

# Define the width of each bar
bar_width = 0.35

# Create the x-axis positions for the bars
x = np.arange(len(male_residence_percentage))

# Create the bar plot
fig, ax = plt.subplots()
ax.bar(x - bar_width/2, male_residence_percentage, width=bar_width, label='Men')
ax.bar(x + bar_width/2, female_residence_percentage, width=bar_width, label='Women')

plt.xlabel('Movement')
plt.ylabel('Percentage')
plt.title(' Men and Women and Movement_Type')
plt.legend()

# Add percentage labels to the top of each bar
for i, p in enumerate(ax.patches):
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

# Adjust x-axis tick labels
ax.set_xticks(x)
ax.set_xticklabels(male_residence_percentage.index)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

religions = ['Maloya', 'Dhanas', 'Ram Darbar', 'Sector 49', 'Sector 38W', 'Mauli Jagran 2/Sundarnagar']

# Create empty lists to store residence percentages for each religion
religion_residence_percentages = []

# Iterate over each religion
for religion in religions:
    # Filter data for the current religion
    religion_data = df2[df2['Place of current residence'] == religion]
    
    # Calculate the percentage of individuals from the current religion living in each residence
    residence_percentages = religion_data['What was the nature of your movement?'].value_counts(normalize=True) * 100
    
    # Append the residence percentages to the list
    religion_residence_percentages.append(residence_percentages)

# Define the width of each bar
bar_width = 0.15

# Create the x-axis positions for the bars
x = np.arange(len(religion_residence_percentages[0]))

# Create the bar plot
fig, ax = plt.subplots()
for i in range(len(religions)):
    ax.bar(x + (i - 2.5) * bar_width, religion_residence_percentages[i], width=bar_width, label=religions[i])

plt.xlabel('Type of Movement')
plt.ylabel('Percentage')
plt.title('Distribution of Movement Types in Diff Residences')
plt.legend()

# Add percentage labels to the top of each bar
for i in range(len(religions)):
    for j, p in enumerate(ax.patches[i * len(x): (i + 1) * len(x)]):
        ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

# Adjust x-axis tick labels
ax.set_xticks(x)
ax.set_xticklabels(religion_residence_percentages[0].index)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/ayushh/chdproject/chd.ipynb Cell 12 in 2
#      <a href='vscode-notebook-cell:/home/ayushh/chdproject/chd.ipynb#X31sZmlsZQ%3D%3D?line=26'>27</a> fig, ax = plt.subplots()
#      <a href='vscode-notebook-cell:/home/ayushh/chdproject/chd.ipynb#X31sZmlsZQ%3D%3D?line=27'>28</a> for i in range(len(religions)):
# ---> <a href='vscode-notebook-cell:/home/ayushh/chdproject/chd.ipynb#X31sZmlsZQ%3D%3D?line=28'>29</a>     ax.bar(x + (i - 2.5) * bar_width, religion_residence_percentages[i], width=bar_width, label=religions[i])
#      <a href='vscode-notebook-cell:/home/ayushh/chdproject/chd.ipynb#X31sZmlsZQ%3D%3D?line=30'>31</a> plt.xlabel('Type of Movement')
#      <a href='vscode-notebook-cell:/home/ayushh/chdproject/chd.ipynb#X31sZmlsZQ%3D%3D?line=31'>32</a> plt.ylabel('Percentage')
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:2391, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2388     if yerr is not None:
#    2389         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2391 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2392     # Make args iterable too.
#    2393     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2395 # Now that units have been converted, set the tick locations.
#    2396 if orientation == 'vertical':
#
# File <__array_function__ internals>:180, in broadcast_arrays(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/stride_tricks.py:540, in broadcast_arrays(subok, *args)
#     533 # nditer is not used here to avoid the limit of 32 arrays.
#     534 # Otherwise, something like the following one-liner would suffice:
#     535 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     536 #                  order='C').itviews
#     538 args = [np.array(_m, copy=False, subok=subok) for _m in args]
# --> 540 shape = _broadcast_shape(*args)
#     542 if all(array.shape == shape for array in args):
#     543     # Common case where nothing needs to be broadcasted.
#     544     return args
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/stride_tricks.py:422, in _broadcast_shape(*args)
#     417 """Returns the shape of the arrays that would result from broadcasting the
#     418 supplied arrays against each other.
#     419 """
#     420 # use the old-iterator because np.nditer does not handle size 0 arrays
#     421 # consistently
# --> 422 b = np.broadcast(*args[:32])
#     423 # unfortunately, it cannot handle 32 or more arguments directly
#     424 for pos in range(32, len(args), 31):
#     425     # ironically, np.broadcast does not properly handle np.broadcast
#     426     # objects (it treats them as scalars)
#     427     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (2,) and arg 1 with shape (3,).

# %%
# error is mainly in the number of bars that need to be combined -- geometrical errors


import numpy as np
import matplotlib.pyplot as plt

# Filter data for men
maloya_data = df[df['Place of current residence'] == 'Maloya']
male_residence_percentage = maloya_data['What was the nature of your movement?'].value_counts(normalize=True) * 100

# Filter data for women
Dhanas_data = df[df['Place of current residence'] == 'Dhanas']
female_residence_percentage = Dhanas_data['What was the nature of your movement?'].value_counts(normalize=True) * 100

# Filter data for women
sec38_data = df[df['Place of current residence'] == 'Sector 38W']
a_residence_percentage = sec38_data['What was the nature of your movement?'].value_counts(normalize=True) * 100

# Filter data for women
sec49_data = df[df['Place of current residence'] == 'Sector 49']
b_residence_percentage = sec49_data['What was the nature of your movement?'].value_counts(normalize=True) * 100

# Filter data for women
rd_data = df[df['Place of current residence'] == 'Ram Darbar']
c_residence_percentage = rd_data['What was the nature of your movement?'].value_counts(normalize=True) * 100

# Filter data for women
mauli_data = df[df['Place of current residence'] == 'Mauli Jagran 2/Sundarnagar']
d_residence_percentage = mauli_data['What was the nature of your movement?'].value_counts(normalize=True) * 100



# Define the width of each bar
bar_width = 0.05

# Create the x-axis positions for the bars
x = np.arange(len(male_residence_percentage))

# Create the bar plot
fig, ax = plt.subplots()
ax.bar(x - 3*bar_width/6, male_residence_percentage, width=bar_width, label='Maloya')
ax.bar(x + 2*bar_width/6, female_residence_percentage, width=bar_width, label='Dhanas')
ax.bar(x - 2*bar_width/6, a_residence_percentage, width=bar_width, label='Sec 38W')
ax.bar(x + bar_width/6, b_residence_percentage, width=bar_width, label='Sec 49')
ax.bar(x - bar_width/6, c_residence_percentage, width=bar_width, label='Ram Darbar')
ax.bar(x + 3*bar_width/6, d_residence_percentage, width=bar_width, label='Mauli Jagran')

plt.xlabel('Movement')
plt.ylabel('Percentage')
plt.title(' Place and Movement_Type')
plt.legend()

# Add percentage labels to the top of each bar
for i, p in enumerate(ax.patches):
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

# Adjust x-axis tick labels
ax.set_xticks(x)
ax.set_xticklabels(male_residence_percentage.index)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/ayushh/chdproject/chd.ipynb Cell 13 in 4
#      <a href='vscode-notebook-cell:/home/ayushh/chdproject/chd.ipynb#X30sZmlsZQ%3D%3D?line=39'>40</a> fig, ax = plt.subplots()
#      <a href='vscode-notebook-cell:/home/ayushh/chdproject/chd.ipynb#X30sZmlsZQ%3D%3D?line=40'>41</a> ax.bar(x - 3*bar_width/6, male_residence_percentage, width=bar_width, label='Maloya')
# ---> <a href='vscode-notebook-cell:/home/ayushh/chdproject/chd.ipynb#X30sZmlsZQ%3D%3D?line=41'>42</a> ax.bar(x + 2*bar_width/6, female_residence_percentage, width=bar_width, label='Dhanas')
#      <a href='vscode-notebook-cell:/home/ayushh/chdproject/chd.ipynb#X30sZmlsZQ%3D%3D?line=42'>43</a> ax.bar(x - 2*bar_width/6, a_residence_percentage, width=bar_width, label='Sec 38W')
#      <a href='vscode-notebook-cell:/home/ayushh/chdproject/chd.ipynb#X30sZmlsZQ%3D%3D?line=43'>44</a> ax.bar(x + bar_width/6, b_residence_percentage, width=bar_width, label='Sec 49')
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/__init__.py:1423, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1420 @functools.wraps(func)
#    1421 def inner(ax, *args, data=None, **kwargs):
#    1422     if data is None:
# -> 1423         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1425     bound = new_sig.bind(ax, *args, **kwargs)
#    1426     auto_label = (bound.arguments.get(label_namer)
#    1427                   or bound.kwargs.get(label_namer))
#
# File ~/.local/lib/python3.10/site-packages/matplotlib/axes/_axes.py:2391, in Axes.bar(self, x, height, width, bottom, align, **kwargs)
#    2388     if yerr is not None:
#    2389         yerr = self._convert_dx(yerr, y0, y, self.convert_yunits)
# -> 2391 x, height, width, y, linewidth, hatch = np.broadcast_arrays(
#    2392     # Make args iterable too.
#    2393     np.atleast_1d(x), height, width, y, linewidth, hatch)
#    2395 # Now that units have been converted, set the tick locations.
#    2396 if orientation == 'vertical':
#
# File <__array_function__ internals>:180, in broadcast_arrays(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/stride_tricks.py:540, in broadcast_arrays(subok, *args)
#     533 # nditer is not used here to avoid the limit of 32 arrays.
#     534 # Otherwise, something like the following one-liner would suffice:
#     535 # return np.nditer(args, flags=['multi_index', 'zerosize_ok'],
#     536 #                  order='C').itviews
#     538 args = [np.array(_m, copy=False, subok=subok) for _m in args]
# --> 540 shape = _broadcast_shape(*args)
#     542 if all(array.shape == shape for array in args):
#     543     # Common case where nothing needs to be broadcasted.
#     544     return args
#
# File ~/.local/lib/python3.10/site-packages/numpy/lib/stride_tricks.py:422, in _broadcast_shape(*args)
#     417 """Returns the shape of the arrays that would result from broadcasting the
#     418 supplied arrays against each other.
#     419 """
#     420 # use the old-iterator because np.nditer does not handle size 0 arrays
#     421 # consistently
# --> 422 b = np.broadcast(*args[:32])
#     423 # unfortunately, it cannot handle 32 or more arguments directly
#     424 for pos in range(32, len(args), 31):
#     425     # ironically, np.broadcast does not properly handle np.broadcast
#     426     # objects (it treats them as scalars)
#     427     # use broadcasting to avoid allocating the full array
#
# ValueError: shape mismatch: objects cannot be broadcast to a single shape.  Mismatch is between arg 0 with shape (2,) and arg 1 with shape (3,).

# %%
grouped_data = df2.groupby(['Age','What was the nature of your movement?']).size().unstack()

# Plotting the grouped chart
grouped_data.plot(kind='bar', stacked=True)

# Set labels and title
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age and Nature')

plt.legend(title='Nature')

plt.show()

# %%
maloya_male = df2[df2['Age'] == '14-20']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('Percentage of Movement type for age 14-20')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
maloya_male = df2[df2['Age'] == '21-30']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('Percentage of Movement type for age 21-30')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
maloya_male = df2[df2['Age'] == '31-40']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('Percentage of Movement type for age 31-40')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
maloya_male = df2[df2['Age'] == '41-50']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('Percentage of Movement type for age 41-50')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
maloya_male = df2[df2['Age'] == '51-60']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('Percentage of Movement type for age 51-60')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
maloya_male = df2[df2['Age'] == '60+']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('Percentage of Movement type for age 60+')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
grouped_data = df2.groupby(['How is the law and order situation (mahaul) compared to where you lived before?','What was the nature of your movement?']).size().unstack()

# Plotting the grouped chart
grouped_data.plot(kind='bar', stacked=True)

# Set labels and title
plt.xlabel('Mahaul')
plt.ylabel('Count')
plt.title('Mahual and Nature')

plt.legend(title='Nature')

plt.show()

# %%
grouped_data = df2.groupby(['What was the nature of your movement?','How is the law and order situation (mahaul) compared to where you lived before?']).size().unstack()

# Plotting the grouped chart
grouped_data.plot(kind='bar', stacked=True)

# Set labels and title
plt.xlabel('Mahaul')
plt.ylabel('Count')
plt.title('Mahaul and Nature')

plt.legend(title='Nature')

plt.show()

# %%
maloya_male = df2[df2['How is the law and order situation (mahaul) compared to where you lived before?'] == 'Same']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('People who Answered Same to Mahaul Comparison')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
maloya_male = df2[df2['How is the law and order situation (mahaul) compared to where you lived before?'] == 'Worse']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('People who Answered worse to Mahaul Comparison')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
maloya_male = df2[df2['How is the law and order situation (mahaul) compared to where you lived before?'] == 'Better']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('People who Answered Better to Mahaul Comparison')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()

# %%
maloya_male = df2[df2['How is the law and order situation (mahaul) compared to where you lived before?'] == 'Don\'t know']
residence_percentage = maloya_male['What was the nature of your movement?'].value_counts(normalize=True) * 100
ax= residence_percentage.plot(kind='bar')

plt.xlabel('Movement_type')
plt.ylabel('Percentage')
plt.title('People who Answered Dont Know to Mahaul Comparison')
for p in ax.patches:
    ax.annotate(f'{p.get_height():.2f}%', (p.get_x() + p.get_width() / 2, p.get_height()), ha='center', va='bottom')

plt.show()
